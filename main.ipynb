# %%
import pandas as pd
from mylib.lib import (
    load_dataset,
    grab_mean,
    grab_median,
    grab_std_deviation,
    grab_min,
    grab_max,
    age_histogram,
    gender_pie_chart,
)

dataset = "dataset/police_killings.csv"

# %%
content_df = load_dataset(dataset)
assert content_df is not None  # Make sure file is not empty
content_df.head()
# Out:
#                  name   age gender    raceethnicity     month  day  year  \
# 0  A'donte Washington  16.0   Male            Black  February   23  2015
# 1      Aaron Rutledge  27.0   Male            White     April    2  2015
# 2         Aaron Siler  26.0   Male            White     March   14  2015
# 3        Aaron Valdez  25.0   Male  Hispanic/Latino     March   11  2015
# 4        Adam Jovicic  29.0   Male            White     March   19  2015
#
#             streetaddress          city state  ...  share_hispanic  p_income  \
# 0            Clearview Ln     Millbrook    AL  ...             5.6     28375
# 1  300 block Iris Park Dr     Pineville    LA  ...             0.5     14678
# 2    22nd Ave and 56th St       Kenosha    WI  ...            16.8     25286
# 3       3000 Seminole Ave    South Gate    CA  ...            98.8     17194
# 4          364 Hiwood Ave  Munroe Falls    OH  ...             1.7     33954
#
# ...

# %%
testing_mean = grab_mean(content_df, "day")
testing_median = grab_median(content_df, "day")
testing_std_deviation = grab_std_deviation(content_df, "day")
testing_min = grab_min(content_df, "day")
testing_max = grab_max(content_df, "day")
describe_test = content_df.describe()
assert describe_test.loc["mean", "day"] == testing_mean
assert describe_test.loc["50%", "day"] == testing_median
assert describe_test.loc["std", "day"] == testing_std_deviation
assert describe_test.loc["min", "day"] == testing_min
assert describe_test.loc["max", "day"] == testing_max

# %%
age_histogram(content_df, True)

# %%
gender_pie_chart(content_df, True)
